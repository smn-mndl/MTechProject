# %% [markdown]
# <a href="https://colab.research.google.com/github/smn-mndl/MTechProject/blob/web-crawler/Web_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
! pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import urllib.request,sys,time

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import pandas as pd

# %%
#url of the page that we want to Scarpe
#+str() is used to convert int datatype of the page no. and concatenate that to a URL for pagination purposes.
URL = 'https://www.anandabazar.com/?page='+str(1)
#Use the browser to get the URL. This is a suspicious command that might blow up.
page = requests.get(URL)

# %%
page.status_code
# Out:
# 200

# %%
# page.content

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
links=soup.find_all('div',attrs={'class':'container'})
# links

# %%
links = soup.find_all("a")

# %%
linkList = []
for j in links:
  # print(list(j.attrs)[0])
  if list(j.attrs)[0] == 'data-widget' and len(j['href']) >= 50:
    linkList.append(j['href'])
# linkList
linkList.pop(0)
# Out:
# 'https://www.abpweddings.com/marketing-register-free-1?utm_source=Anandabazardigital&utm_medium=website+msite&utm_campaign=patropatritab&utm_term=bengali&img=bengali_marketing-register-free-1-2.jpg'

# %%
theurl = "https://www.anandabazar.com/"+linkList[1]
thepage = urllib.request.urlopen(theurl)

soup = BeautifulSoup(thepage)

# project_href = [i['href'] for i in soup.find_all('a', href=True)]
# print(soup.find("div",attrs={'class':'articlebox'}))
print(soup.find("div",attrs={'class':'articlebox'}).find("h1", attrs={'class': 'mt-8'}).text.strip())
# Out:
# সিদ্দারামাইয়া এবং শিবকুমারের সঙ্গে বৈঠক খড়্গের, বুধে নাম ঘোষণা কর্নাটকের মুখ্যমন্ত্রীর?

# %%
headerList = []
for i in linkList:
  theurl = "https://www.anandabazar.com/"+i
  # print(theurl)
  thepage = urllib.request.urlopen(theurl)

  soup = BeautifulSoup(thepage)
  headerList.append(soup.find("div",attrs={'class':'articlebox'}).find("h1", attrs={'class': 'mt-8'}).text.strip())
  print(soup.find("div",attrs={'class':'articlebox'}).find("h1", attrs={'class': 'mt-8'}).text.strip())
  print('\n')
# Out:
# নতুন ফ্ল্যাট দেখতে এসে ১৮ তলা থেকে মরণঝাঁপ! তরুণীর মৃত্যুতে চাঞ্চল্য কামালগাজিতে
#
#
# সিদ্দারামাইয়া এবং শিবকুমারের সঙ্গে বৈঠক খড়্গের, বুধে নাম ঘোষণা কর্নাটকের মুখ্যমন্ত্রীর?
#
#
# ৩৬০০০ চাকরি ও ববিতা: কয়েক মিনিটের ব্যবধানে বিচারপতি গঙ্গোপাধ্যায়ের জোড়া রায় ‘সংশোধন’
#
#
# মুখ্যমন্ত্রী নির্দেশ দিতেই এগরায় বিস্ফোরণস্থলে সিআইডির বম্ব ডিসপোজাল স্কোয়াড ও ফরেন্সিক দল
#
#
# ব্যোমকেশের খোলস ছেড়ে আবির নতুন এক গোয়েন্দার চরিত্রে, নেপথ্যে দেবালয়
#
#
# তিন কন্যা এবং এক চাকরির গল্প
#
#
# সিভিল সার্ভিসেস পরীক্ষার জন্য মে-র শেষ রবিবার মেট্রোর সূচিতে বদল, ক’টা থেকে প্রথম ট্রেন?
#
#
# ‘একলা চলো’ থেকে ‘হাত’ ধরার বার্তা, লোকসভা ভোটের লক্ষ্যে জোট নিয়ে নীতিবদল করছে তৃণমূল?
#
#
# ভিকি-ক্যাটের নাকি বনিবনা হচ্ছে না, স্বামীর জন্মদিনে কী লিখলেন অভিনেত্রী?
#
#
# ৮৯ রান স্টোইনিসের, ক্রুণালের ব্যাটে ৪৯, রোহিতের মুম্বইকে ১৭৮ রানের লক্ষ্য দিল লখনউ
#
#
# বার বার ওপেনার বদলেও সাফল্য নেই, কেকেআরে কি এ বার লিটনের বদলে আসা বিশ্বকাপজয়ী ব্যাটার?
#
#
# ...

# %%
len(headerList)
# Out:
# 111
